# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

sns.set_theme()

# %%
data = pd.read_csv(r'C:\Users\bukab\OneDrive\Desktop\project\datasets\jobs_in_data.csv')
data
# Out:
#       work_year                 job_title                    job_category  \
# 0          2023      Data DevOps Engineer                Data Engineering
# 1          2023            Data Architect  Data Architecture and Modeling
# 2          2023            Data Architect  Data Architecture and Modeling
# 3          2023            Data Scientist       Data Science and Research
# 4          2023            Data Scientist       Data Science and Research
# ...         ...                       ...                             ...
# 9350       2021           Data Specialist    Data Management and Strategy
# 9351       2020            Data Scientist       Data Science and Research
# 9352       2021  Principal Data Scientist       Data Science and Research
# 9353       2020            Data Scientist       Data Science and Research
# 9354       2020     Business Data Analyst                   Data Analysis
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9355 entries, 0 to 9354
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           9355 non-null   int64
#  1   job_title           9355 non-null   object
#  2   job_category        9355 non-null   object
#  3   salary_currency     9355 non-null   object
#  4   salary              9355 non-null   int64
#  5   salary_in_usd       9355 non-null   int64
#  6   employee_residence  9355 non-null   object
#  7   experience_level    9355 non-null   object
#  8   employment_type     9355 non-null   object
#  9   work_setting        9355 non-null   object
#  10  company_location    9355 non-null   object
#  11  company_size        9355 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 877.2+ KB

# %%
sns.barplot(data['work_setting'])
# Out:
# <Axes: ylabel='work_setting'>

# %% [markdown]
# Scatter Plot

# %%
sns.scatterplot(data=data, x='work_year', y='salary')
# Out:
# <Axes: xlabel='work_year', ylabel='salary'>

# %%
sns.stripplot(data=data, x='work_year', y='salary', 
              jitter=False, 
              dodge=True, 
              hue='experience_level'
              )
# Out:
# <Axes: xlabel='work_year', ylabel='salary'>

# %% [markdown]
# Salary Distribution

# %%
sns.histplot(data=data, x='salary', hue='job_category', element='step')
# Out:
# <Axes: xlabel='salary', ylabel='Count'>

# %% [markdown]
# Salary by job title

# %%
data[['job_title', 'salary']]
# Out:
#                      job_title  salary
# 0         Data DevOps Engineer   88000
# 1               Data Architect  186000
# 2               Data Architect   81800
# 3               Data Scientist  212000
# 4               Data Scientist   93300
# ...                        ...     ...
# 9350           Data Specialist  165000
# 9351            Data Scientist  412000
# 9352  Principal Data Scientist  151000
# 9353            Data Scientist  105000
# 9354     Business Data Analyst  100000
#
# [9355 rows x 2 columns]

# %%
data['job_title'].describe()
# Out:
# count              9355
# unique              125
# top       Data Engineer
# freq               2195
# Name: job_title, dtype: object

# %%
# Calculate average salary for each job title
average_salary_by_title = data.groupby('job_title')['salary_in_usd'].mean().sort_values(ascending=False)

# Select top N job titles
top_n_titles = 20
top_titles = average_salary_by_title.head(top_n_titles).index

# Filter data for top job titles
data_top_titles = data[data['job_title'].isin(top_titles)]

plt.figure(figsize=(14, 8))
sns.barplot(data=data_top_titles, x='salary_in_usd', y='job_title', errorbar=None, palette='viridis')

plt.title(f'Top {top_n_titles} Job Titles with Highest Average Salary')
plt.xlabel('Average Salary (USD)')
plt.ylabel('Job Title')
plt.show()
# Out:
# C:\Users\bukab\AppData\Local\Temp\ipykernel_75756\147888879.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data_top_titles, x='salary_in_usd', y='job_title', errorbar=None, palette='viridis')

# %% [markdown]
# Salary Heatmap

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9355 entries, 0 to 9354
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           9355 non-null   int64
#  1   job_title           9355 non-null   object
#  2   job_category        9355 non-null   object
#  3   salary_currency     9355 non-null   object
#  4   salary              9355 non-null   int64
#  5   salary_in_usd       9355 non-null   int64
#  6   employee_residence  9355 non-null   object
#  7   experience_level    9355 non-null   object
#  8   employment_type     9355 non-null   object
#  9   work_setting        9355 non-null   object
#  10  company_location    9355 non-null   object
#  11  company_size        9355 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 877.2+ KB

# %%
data_heatmap = data.pivot_table(index='experience_level', columns='job_title', values='salary_in_usd', aggfunc='median')
sns.heatmap(data_heatmap)
# Out:
# <Axes: xlabel='job_title', ylabel='experience_level'>
